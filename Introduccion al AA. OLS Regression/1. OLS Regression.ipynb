# %%
import pandas as pd

data = {
    'boot_size' : [ 39, 38, 37, 39, 38, 35, 37, 36, 35, 40, 
                    40, 36, 38, 39, 42, 42, 36, 36, 35, 41, 
                    42, 38, 37, 35, 40, 36, 35, 39, 41, 37, 
                    35, 41, 39, 41, 42, 42, 36, 37, 37, 39,
                    42, 35, 36, 41, 41, 41, 39, 39, 35, 39
 ],
    'harness_size': [ 58, 58, 52, 58, 57, 52, 55, 53, 49, 54,
                59, 56, 53, 58, 57, 58, 56, 51, 50, 59,
                59, 59, 55, 50, 55, 52, 53, 54, 61, 56,
                55, 60, 57, 56, 61, 58, 53, 57, 57, 55,
                60, 51, 52, 56, 55, 57, 58, 57, 51, 59
                ]
}

dataset = pd.DataFrame(data)
dataset
# Out:
#     boot_size  harness_size
# 0          39            58
# 1          38            58
# 2          37            52
# 3          39            58
# 4          38            57
# 5          35            52
# 6          37            55
# 7          36            53
# 8          35            49
# 9          40            54
# 10         40            59
# 11         36            56
# 12         38            53
# 13         39            58
# 14         42            57
# 15         42            58
# 16         36            56
# 17         36            51
# 18         35            50
# 19         41            59
# 20         42            59
# 21         38            59
# 22         37            55
# 23         35            50
# 24         40            55
# 25         36            52
# 26         35            53
# 27         39            54
# 28         41            61
# 29         37            56
# 30         35            55
# 31         41            60
# ...

# %%
#OLS Regression
import statsmodels.formula.api as smf

# boot_size is explained by harness_size
formula = 'boot_size ~ harness_size'

model = smf.ols(formula, data=dataset)

if not hasattr(model, 'params'):
    print('Model has no params attribute, train it.')
# Out:
# Model has no params attribute, train it.

# %%
import graphing

fitted_model = model.fit()

print("The following model parameters have been found:\n" +
        f"Line slope: {fitted_model.params[1]}\n"+
        f"Line Intercept: {fitted_model.params[0]}")
# Out:
# The following model parameters have been found:
# Line slope: 0.5859254167382717
# Line Intercept: 5.719109812682555

# %%
graphing.scatter_2D(dataset, label_x='harness_size', 
                    label_y='boot_size',
                    trendline=lambda x: fitted_model.params[1] * x + fitted_model.params[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\IPython\core\formatters.py:920, in IPythonDisplayFormatter.__call__(self, obj)
#     918 method = get_real_method(obj, self.print_method)
#     919 if method is not None:
# --> 920     method()
#     921     return True
#
# File c:\Users\elias\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File c:\Users\elias\AppData\Local\Programs\Python\Python311\Lib\site-packages\plotly\io\_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
# ...

# %%
harness_size = {'harness_size' : [52.5]}
aprox_boot_size = fitted_model.predict(harness_size)

print(f"Recommended boot size for {harness_size['harness_size']} is {aprox_boot_size[0]}")
# Out:
# Recommended boot size for [52.5] is 36.48019419144182
